# %%
import mne
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

# %%
def data_fetch(i, j):
    if i < 10:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S00{}/S00{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S00{}/S00{}R{}.edf'.format(i,i,j), preload = True)
    elif i >= 10 and i < 100:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S0{}/S0{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S0{}/S0{}R{}.edf'.format(i,i,j), preload = True)

    else:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S{}/S{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S{}/S{}R{}.edf'.format(i,i,j), preload = True)

            
    raw.rename_channels(lambda s: s.strip('.'))
    events_from_annot, event_dict = mne.events_from_annotations(raw)
    raw.set_eeg_reference("average", projection = True)
    
    #montages
    montage = mne.channels.read_montage("standard_1020")
    raw.set_montage(montage)
    raw.filter(l_freq=6, h_freq=40)
    
    #events
    events = events_from_annot
    
    #epochs
    tmin, tmax = -0.2, 0.5
    event_id = {'Auditory/Left': 2, 'Auditory/Right': 3}

    baseline = (None, 0.0)
    epochs = mne.Epochs(raw, events=events, event_id=event_id, tmin=tmin,
                        tmax=tmax, baseline=baseline,
                        picks=('eeg'))  # only include EEG
    picks = mne.pick_types(epochs.info, meg=False, eeg=True)
    evoked_left = epochs['Auditory/Left'].average(picks=picks)
    evoked_right = epochs['Auditory/Right'].average(picks=picks)
    left_data = evoked_left.data
    right_data = evoked_right.data
    
    return left_data, right_data

# %%
left_data = []
right_data = []
for i in range(1,110):
    for j in range(3,14):
        if i != 88 and i != 92 and i != 100:
            x, y = data_fetch(i, j)
            print(i, j, '___________________________________________________________________________________')
            left_data.append(x)
            right_data.append(y)
# Out:
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 3 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 4 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 5 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 6 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 7 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 8 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 9 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 10 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 11 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 12 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 1 13 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 3 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 4 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 5 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 6 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 7 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 2 8 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S002\S002R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 8 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S109\S109R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 9 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S109\S109R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# Applying baseline correction (mode: mean)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 10 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S109\S109R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# 15 matching events found
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 11 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S109\S109R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 12 ___________________________________________________________________________________
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S109\S109R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\mne\utils\docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# <ipython-input-2-12683f694796>:26: DeprecationWarning: Setting a montage using anything rather than DigMontage is deprecated and will raise an error in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_dig_polhemus_isotrak``, or ``read_dig_captrack`` ``read_dig_hpts``, ``read_dig_captrack`` or ``read_custom_montage`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays.
#   raw.set_montage(montage)
# 15 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# 109 13 ___________________________________________________________________________________

# %%
left_array = np.array(left_data)
left_array1 = preprocessing(left_array)

right_array = np.array(right_data)
right_array1 = preprocessing(right_array)

# %%
right_array.shape
# Out:
# (1166, 64, 113)

# %%
zeros = np.zeros(shape=(1166,))

# %%
ones = np.ones(shape=(1166,))

# %%
data = np.concatenate((left_array1, right_array1), axis = 0)

# %%
data.shape
# Out:
# (2332, 64, 113)

# %%
events = np.concatenate((zeros, ones), axis = 0)

# %%
def preprocessing(data):
    mean = np.mean(data, axis = 0)    
    var = np.var(data, axis = 0)
    data = (data - mean)/var
    return data
#data_array = preprocessing(data)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import metrics
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import MaxPooling1D, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU

# %%
###################################################################################

# %%
new_data = data.reshape((2332, 7232, 1))

# %%
def preprocessing(data):
    mean = np.mean(data, axis = 0)    
    var = np.var(data, axis = 0)
    data = (data - mean)/var
    return data
new_data_array = preprocessing(new_data)

# %%
x_train, x_test, y_train, y_test = train_test_split(new_data, events, test_size=0.2, random_state=42)
x_train.shape
# Out:
# (1865, 7232, 1)

# %%
def create_model():
    # create model
    model = Sequential()
    model.add(Conv1D(filters=14, kernel_size=3, activation='relu', input_shape=(7232,1)))
    model.add(Conv1D(filters=14, kernel_size=3, activation='relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(15, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))


    # Compile model
    model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['binary_accuracy'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 7230, 14)          56
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 7228, 14)          602
# _________________________________________________________________
# dropout (Dropout)            (None, 7228, 14)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3614, 14)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 50596)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                2529850
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                765
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 2,533,839
# Trainable params: 2,533,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Train on 1865 samples, validate on 467 samples
# Epoch 1/50
# 1865/1865 [==============================] - 28s 15ms/sample - loss: 8294.9747 - binary_accuracy: 0.5995 - val_loss: 1198.1649 - val_binary_accuracy: 0.7173
# Epoch 2/50
# 1865/1865 [==============================] - 27s 15ms/sample - loss: 461.4324 - binary_accuracy: 0.8745 - val_loss: 295.4617 - val_binary_accuracy: 0.9165
# Epoch 3/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 55.9474 - binary_accuracy: 0.9641 - val_loss: 250.5702 - val_binary_accuracy: 0.9379
# Epoch 4/50
# 1865/1865 [==============================] - 25s 14ms/sample - loss: 34.1280 - binary_accuracy: 0.9812 - val_loss: 204.2329 - val_binary_accuracy: 0.9358
# Epoch 5/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 26.8113 - binary_accuracy: 0.9855 - val_loss: 198.7568 - val_binary_accuracy: 0.9443
# Epoch 6/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 9.0057 - binary_accuracy: 0.9925 - val_loss: 204.1867 - val_binary_accuracy: 0.9293
# Epoch 7/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 25.2701 - binary_accuracy: 0.9823 - val_loss: 156.9811 - val_binary_accuracy: 0.9443
# Epoch 8/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 23.8193 - binary_accuracy: 0.9823 - val_loss: 136.1682 - val_binary_accuracy: 0.9593
# Epoch 9/50
# 1865/1865 [==============================] - 20s 11ms/sample - loss: 3.3763 - binary_accuracy: 0.9952 - val_loss: 80.8019 - val_binary_accuracy: 0.9679
# Epoch 10/50
# 1865/1865 [==============================] - 25s 13ms/sample - loss: 9.6563 - binary_accuracy: 0.9903 - val_loss: 93.2590 - val_binary_accuracy: 0.9657
# Epoch 11/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 24.2583 - binary_accuracy: 0.9818 - val_loss: 104.3749 - val_binary_accuracy: 0.9465
# Epoch 12/50
# 1865/1865 [==============================] - 25s 13ms/sample - loss: 2.9791 - binary_accuracy: 0.9941 - val_loss: 290.7336 - val_binary_accuracy: 0.9251
# Epoch 13/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 10.4151 - binary_accuracy: 0.9925 - val_loss: 74.7712 - val_binary_accuracy: 0.9679
# Epoch 14/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 4.6086 - binary_accuracy: 0.9962 - val_loss: 37.4919 - val_binary_accuracy: 0.9743
# Epoch 15/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 6.3876 - binary_accuracy: 0.9957 - val_loss: 59.8328 - val_binary_accuracy: 0.9743
# Epoch 16/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 2.9976 - binary_accuracy: 0.9989 - val_loss: 46.8524 - val_binary_accuracy: 0.9743
# Epoch 17/50
# 1865/1865 [==============================] - 22s 12ms/sample - loss: 4.1480 - binary_accuracy: 0.9957 - val_loss: 58.1422 - val_binary_accuracy: 0.9679
# Epoch 18/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 1.3712 - binary_accuracy: 0.9989 - val_loss: 71.9273 - val_binary_accuracy: 0.9615
# Epoch 19/50
# 1865/1865 [==============================] - 22s 12ms/sample - loss: 10.7195 - binary_accuracy: 0.9914 - val_loss: 74.8938 - val_binary_accuracy: 0.9679
# Epoch 20/50
# 1865/1865 [==============================] - 25s 14ms/sample - loss: 11.4080 - binary_accuracy: 0.9946 - val_loss: 194.9607 - val_binary_accuracy: 0.9379
# Epoch 21/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 5.5455 - binary_accuracy: 0.9957 - val_loss: 166.4758 - val_binary_accuracy: 0.9336
# Epoch 22/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 6.3031 - binary_accuracy: 0.9936 - val_loss: 167.0903 - val_binary_accuracy: 0.9422
# Epoch 23/50
# 1865/1865 [==============================] - 25s 13ms/sample - loss: 5.9771e-31 - binary_accuracy: 1.0000 - val_loss: 61.8593 - val_binary_accuracy: 0.9722
# Epoch 24/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 5.7556 - binary_accuracy: 0.9946 - val_loss: 63.3768 - val_binary_accuracy: 0.9764
# Epoch 25/50
# 1865/1865 [==============================] - 30s 16ms/sample - loss: 5.2626 - binary_accuracy: 0.9941 - val_loss: 95.3389 - val_binary_accuracy: 0.9700
# Epoch 26/50
# 1865/1865 [==============================] - 26s 14ms/sample - loss: 4.6237 - binary_accuracy: 0.9952 - val_loss: 73.1894 - val_binary_accuracy: 0.9572
# Epoch 27/50
# 1865/1865 [==============================] - 23s 13ms/sample - loss: 36.7971 - binary_accuracy: 0.9812 - val_loss: 71.1110 - val_binary_accuracy: 0.9722
# Epoch 28/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 7.1158 - binary_accuracy: 0.9957 - val_loss: 29.7038 - val_binary_accuracy: 0.9786
# Epoch 29/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 2.9849 - binary_accuracy: 0.9968 - val_loss: 47.6845 - val_binary_accuracy: 0.9807
# Epoch 30/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 6.0727 - binary_accuracy: 0.9968 - val_loss: 25.8424 - val_binary_accuracy: 0.9872
# Epoch 31/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 6.9457 - binary_accuracy: 0.9957 - val_loss: 16.9777 - val_binary_accuracy: 0.9936
# Epoch 32/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 6.1720 - binary_accuracy: 0.9952 - val_loss: 21.5695 - val_binary_accuracy: 0.9829
# Epoch 33/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 8.1710 - binary_accuracy: 0.9941 - val_loss: 34.7895 - val_binary_accuracy: 0.9807
# Epoch 34/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 7.6451 - binary_accuracy: 0.9952 - val_loss: 11.1288 - val_binary_accuracy: 0.9957
# Epoch 35/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 2.2559 - binary_accuracy: 0.9984 - val_loss: 13.1648 - val_binary_accuracy: 0.9957
# Epoch 36/50
# 1865/1865 [==============================] - 23s 12ms/sample - loss: 2.8321 - binary_accuracy: 0.9968 - val_loss: 15.2524 - val_binary_accuracy: 0.9957
# Epoch 37/50
# 1865/1865 [==============================] - 25s 13ms/sample - loss: 0.1726 - binary_accuracy: 0.9989 - val_loss: 10.5088 - val_binary_accuracy: 0.9936
# Epoch 38/50
# 1865/1865 [==============================] - 25s 14ms/sample - loss: 6.5668 - binary_accuracy: 0.9962 - val_loss: 6.7327 - val_binary_accuracy: 0.9936
# Epoch 39/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 3.3703 - binary_accuracy: 0.9962 - val_loss: 14.3664 - val_binary_accuracy: 0.9936
# Epoch 40/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 5.7661 - binary_accuracy: 0.9957 - val_loss: 79.1107 - val_binary_accuracy: 0.9872
# Epoch 41/50
# 1865/1865 [==============================] - 23s 13ms/sample - loss: 17.7126 - binary_accuracy: 0.9920 - val_loss: 48.9145 - val_binary_accuracy: 0.9829
# Epoch 42/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 2.8624 - binary_accuracy: 0.9973 - val_loss: 48.2690 - val_binary_accuracy: 0.9850
# Epoch 43/50
# 1865/1865 [==============================] - 21s 11ms/sample - loss: 0.3197 - binary_accuracy: 0.9973 - val_loss: 58.0216 - val_binary_accuracy: 0.9872
# Epoch 44/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 0.9267 - binary_accuracy: 0.9984 - val_loss: 35.6762 - val_binary_accuracy: 0.9893
# Epoch 45/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 1.6225 - binary_accuracy: 0.9968 - val_loss: 7.5818 - val_binary_accuracy: 0.9936
# Epoch 46/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 4.6104 - binary_accuracy: 0.9962 - val_loss: 20.5689 - val_binary_accuracy: 0.9936
# Epoch 47/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 4.3129 - binary_accuracy: 0.9962 - val_loss: 12.2807 - val_binary_accuracy: 0.9957
# Epoch 48/50
# 1865/1865 [==============================] - 25s 13ms/sample - loss: 1.4727 - binary_accuracy: 0.9979 - val_loss: 16.2153 - val_binary_accuracy: 0.9957
# Epoch 49/50
# 1865/1865 [==============================] - 26s 14ms/sample - loss: 5.6190 - binary_accuracy: 0.9968 - val_loss: 5.2301 - val_binary_accuracy: 0.9957
# Epoch 50/50
# 1865/1865 [==============================] - 24s 13ms/sample - loss: 3.8609 - binary_accuracy: 0.9957 - val_loss: 6.5720 - val_binary_accuracy: 0.9957

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
